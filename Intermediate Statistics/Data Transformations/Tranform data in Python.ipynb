# %% [markdown]
# # Transform Data in Python

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
anime = pd.read_csv(r'C:\Users\nikki\OneDrive\Pictures\Data Science\105 Intermediate Statistics\anime.csv')

# %% [markdown]
# ### Visualizing Tranformation

# %%
# No fitted line
import pandas as pd
anime.aired_from_year.hist()
# Out:
# <AxesSubplot:>

# %%
# Fitted line (?)
sns.displot(anime['aired_from_year'])

# %% [markdown]
# ### Transforming Positively Skewed Data

# %%
anime.scored_by.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Using np.sqrt()

# %%
anime['scored_bySQRT'] = np.sqrt(anime['scored_by'])

# %%
anime.scored_bySQRT.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Using np.log()

# %%
anime['scored_byLOG'] = np.log(anime['scored_by'])
# Out:
# C:\Python3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Dealing with Infinite Values

# %%
anime.dropna(inplace=True)

# %%
# Fixed infinite numbers and graph
anime.scored_byLOG.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Transforming Negatively Skewed Data

# %% [markdown]
# ### Squaring the variable

# %%
anime['aired_from_yearSQ'] = anime['aired_from_year']**2

# %%
anime.aired_from_yearSQ.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Cubing the Variable

# %%
anime['aired_from_yearCUBE'] = anime['aired_from_year']**3

# %%
anime.aired_from_yearCUBE.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # BoxCox Transformation

# %%
# No Guess transformation equivalent to Tukey's Ladder of Power Transformation in R

# %%
from scipy import stats
from scipy.stats import boxcox

# %%
anime['scored_byLOG1'] = boxcox(anime['scored_by'],0)
